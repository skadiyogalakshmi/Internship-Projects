# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([6,7,9,3])
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Modulus:",a%b)
# Out:
# Addition: [ 7  9 12  7]
# Subtraction: [-5 -5 -6  1]
# Multiplication: [ 6 14 27 12]
# Division: [0.16666667 0.28571429 0.33333333 1.33333333]
# Modulus: [1 2 3 1]
